# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
from shapely.geometry import Polygon, Point 
import folium.colormap as cm

# %%
crime_chicago = pd.read_pickle('crime_chicago_with_timestamp.pkl')

# %% [markdown]
# #### Binning

# %%
number_of_bins = 20
no = number_of_bins

lat_min = crime_chicago['Latitude'].min()
lon_min = crime_chicago['Longitude'].min()

lat_span = crime_chicago['Latitude'].max() - crime_chicago['Latitude'].min()
lon_span = crime_chicago['Longitude'].max() - crime_chicago['Longitude'].min()

lat_step = lat_span / no
lon_step = lon_span / no

# %%
crime_chicago['bin'] = \
    no*np.floor((crime_chicago['Longitude']-lon_min)/lon_step) + \
       np.floor((crime_chicago['Latitude'] -lat_min)/lat_step)

# %%
def getCornerLatLonForBin(bin_no):
    return (
        lat_min + (bin_no % no)         *lat_step, 
        lon_min + np.floor(bin_no / no) *lon_step
    )

# %%
def getPolygonForBin(bin_no):
    lat, lon = getCornerLatLonForBin(bin_no)
    return Polygon([
            (lat,            lon),
            (lat,            lon + lon_step),
            (lat + lat_step, lon + lon_step),
            (lat + lat_step, lon),
        ])

# %%
def getPolygonForBinReverse(bin_no):
    lat, lon = getCornerLatLonForBin(bin_no)
    return Polygon([
            (lon,            lat),
            (lon + lon_step, lat),
            (lon + lon_step, lat + lat_step),
            (lon,            lat + lat_step),
        ])

# %% [markdown]
# #### Grouping

# %%
crime_chicago_count = crime_chicago[['bin']].groupby(['bin']).size().reset_index().rename(columns={0:'count'})

# %% [markdown]
# #### Transforming to GeoDataFrame

# %%
crime_chicago_count_gpd = None

# %%
crime_chicago_count_gpd = gpd.GeoDataFrame(crime_chicago_count)

# %%
crime_chicago_count_gpd.geometry = crime_chicago_count_gpd['bin'] \
    .map(lambda x: getPolygonForBinReverse(x))

# %%
max_count = crime_chicago_count_gpd['count'].max()
crime_chicago_count_gpd['relative_count'] = crime_chicago_count_gpd['count']/max_count

# %%
scale = cm.LinearColormap(['green','yellow','red'])
scale
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#018100;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#028100;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#038200;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#048200;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#068300;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#078400;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#088400;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#098500;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0b8600;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0c8600;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#0d8700;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#0e8700;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#108800;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#118900;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#128900;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#138a00;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#158b00;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#168b00;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#178c00;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#188c00;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#1a8d00;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#1b8e00;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#1c8e00;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#1d8f00;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#1e8f00;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#1f9000;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#209000;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#219100;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#229100;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#239200;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#259300;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#269300;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#289400;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#299400;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#2a9500;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#2b9500;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#2c9600;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#2d9600;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#2f9800;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#309800;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#319900;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#329900;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#339a00;stroke-width:3;" /><line x1="51" ...

# %%
scale = cm.LinearColormap(['green','yellow','red']).to_step(n=100, method='log')
scale
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#1f8f00;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#1f8f00;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#1f8f00;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#1f8f00;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#1f8f00;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#299500;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#299500;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#299500;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#299500;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#299500;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#339a00;stroke-width:3;" /><line x1="51" ...

# %%
crime_chicago_count_gpd['style'] = crime_chicago_count_gpd['relative_count'] \
    .map(lambda x: {'fillColor' : scale(x), 'weight' : 0})

# %%
crime_chicago_count_gpd.crs = {'init': 'epsg:4326', 'no_defs': True}

# %%
m = folium.Map([41.80,-87.75], zoom_start=11, tiles='cartodbpositron')

folium.GeoJson(crime_chicago_count_gpd).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# May be useful later

# %%
# m = folium.Map([41.80,-87.75], zoom_start=11, tiles='cartodbpositron')

# folium.GeoJson(
#     crime_chicago_count_gpd,
#     style_function=lambda feature: {
#         'fillColor': linear(crime_chicago_count_gpd[]),
#         'color' : 'black',
#         'weight' : 2,
#         'dashArray' : '5, 5'
#         }).add_to(m)

# m
